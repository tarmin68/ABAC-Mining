# %%
import csv
import numpy as np
#from __future__ import print_function
import numpy as np
import pandas as pd

# %%
##Questions:
   
    # Can you give me a processed version of the data?
    # provide your Code?
    # Should we use dummies

from scipy.io import arff
import pandas as pd

data = arff.loadarff('universityPolicyTrainingData.arff')
#data = arff.loadarff('projectManagementPolicyTrainingData.arff')
df = pd.DataFrame(data[0])

df.head()
# Out:
#        position    udepartment  crstaken crstaught   ischair            type  \
# 0  b'applicant'   b'registrar'  b'cs601'  b'cs602'  b'false'       b'roster'
# 1    b'faculty'  b'admissions'  b'ee601'  b'cs601'   b'true'  b'application'
# 2      b'staff'  b'admissions'  b'ee101'  b'ee602'  b'false'  b'application'
# 3    b'faculty'   b'registrar'  b'cs601'  b'ee602'   b'true'       b'roster'
# 4    b'student'  b'admissions'  b'cs101'  b'ee601'  b'false'    b'gradebook'
#
#         crs odepartment           action
# 0  b'ee602'       b'ee'         b'write'
# 1  b'cs101'       b'cs'     b'setstatus'
# 2  b'cs602'       b'ee'     b'setstatus'
# 3  b'ee602'       b'cs'         b'write'
# 4  b'cs101'       b'cs'  b'readmyscores'

# %%
cat_columns = df.select_dtypes(['category']).columns

print(cat_columns)

df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)

print(df.corr())

file = open('dcorr.csv',"r+") 
#temp = ndf.loc[ndf['cluster'] == 10]
#df.corr= temp.corr()
corr.to_csv('dcorr.csv')
file.close()
# Out:
# Index(['adminrole', 'type', 'udepartment', 'odepartment', 'action', 'resource',
#        'uprojectsled', 'uprojects', 'oproject', 'utasks', 'proprietary',
#        'uexpertise', 'oexpertise', 'isemployee'],
#       dtype='object')
#               adminrole      type  udepartment  odepartment    action  \
# adminrole      1.000000  0.132698    -0.050073    -0.034563  0.032219
# type           0.132698  1.000000     0.135962     0.122247  0.080855
# udepartment   -0.050073  0.135962     1.000000     0.117741  0.127397
# odepartment   -0.034563  0.122247     0.117741     1.000000  0.130664
# action         0.032219  0.080855     0.127397     0.130664  1.000000
# resource       0.004418 -0.129052    -0.005495    -0.020351 -0.095733
# uprojectsled   0.020739  0.014179    -0.014087    -0.013889 -0.164702
# uprojects     -0.426954 -0.076616     0.021874    -0.003461  0.142740
# oproject      -0.386919 -0.046713     0.006484    -0.019208 -0.061417
# ...

# %%
print(df.describe())
df.isnull().values.any()
df["adminrole"] = df["adminrole"].astype('category')
df["type"] = df["type"].astype('category')
df["udepartment"] = df["udepartment"].astype('category')
df["odepartment"] = df["odepartment"].astype('category')
df["action"] = df["action"].astype('category')
df["resource"] = df["resource"].astype('category')
df["uprojectsled"] = df["uprojectsled"].astype('category')
df["oproject"] = df["oproject"].astype('category')
df["uprojects"] = df["uprojects"].astype('category')
df["utasks"] = df["utasks"].astype('category')
df["proprietary"] = df["proprietary"].astype('category')
df["uexpertise"] = df["uexpertise"].astype('category')
df["oexpertise"] = df["oexpertise"].astype('category')
df["isemployee"] = df["isemployee"].astype('category')

df.dtypes
# Out:
#             adminrole     type udepartment odepartment    action resource  \
# count           11000    11000       11000       11000     11000    11000
# unique              4        3           2           2         7        5
# top     b'accountant'  b'task'     b'dep1'     b'dep1'  b'write'  b'res1'
# freq             3314     5000        5956        6026      3000     3064
#
#        uprojectsled uprojects  oproject   utasks proprietary uexpertise  \
# count         11000     11000     11000    11000       11000      11000
# unique            7         7         7        5           2          3
# top        b'proj1'  b'proj3'  b'proj3'  b'res1'    b'false'  b'design'
# freq           2447      2447      2284     2996        5970       4047
#
#        oexpertise isemployee
# count       11000      11000
# unique          3          2
# top     b'coding'    b'true'
# freq         4045       6013
# adminrole       category
# type            category
# udepartment     category
# ...

# %%
"""import pandas_ml as pdml
df = pdml.ModelFrame(df, target='action')
df.has_target()
df.data"""

#ndf=pd.concat([pd.get_dummies(df[col]) for col in df], axis=1, keys=df.columns)
print(df.corr())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from sklearn import datasets
from sklearn.cluster import KMeans
import numpy as np
from kmodes.kmodes import KModes

"""# Declaring Model
model = KMeans(n_clusters=10)

# Fitting Model
model.fit(ndf)

# Predicitng a single input
#predicted_label = model.predict([[7.2, 3.5, 0.8, 1.6]])

# Prediction on the entire data
all_predictions = model.predict(ndf)

# Printing Predictions
print(model.labels_)
print(all_predictions)"""
# Out:
# '# Declaring Model\nmodel = KMeans(n_clusters=10)\n\n# Fitting Model\nmodel.fit(ndf)\n\n# Predicitng a single input\n#predicted_label = model.predict([[7.2, 3.5, 0.8, 1.6]])\n\n# Prediction on the entire data\nall_predictions = model.predict(ndf)\n\n# Printing Predictions\nprint(model.labels_)\nprint(all_predictions)'

# %%
data = df

km = KModes(n_clusters=10, init='Huang', n_init=1, verbose=2)
df_dummy = pd.get_dummies(df)

clusters = km.fit_predict(data)
df_dummy['clusters'] = clusters

# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4141, cost: 63197.0
# Run 1, iteration: 2/100, moves: 415, cost: 63197.0
# [[b'planner' b'schedule' b'dep1' b'dep1' b'write' b'res4' b'proj1'
#   b'proj3' b'proj3' b'res2' b'false' b'test' b'design' b'false']
#  [b'planner' b'task' b'dep1' b'dep2' b'read' b'res1' b'proj7' b'proj4'
#   b'proj4' b'res1' b'true' b'coding' b'coding' b'true']
#  [b'planner' b'schedule' b'dep2' b'dep1' b'read' b'res5' b'proj5'
#   b'proj2' b'proj2' b'res5' b'true' b'test' b'design' b'false']
#  [b'accountant' b'budget' b'dep2' b'dep1' b'write' b'res1' b'proj1'
#   b'proj6' b'proj6' b'res3' b'false' b'coding' b'coding' b'false']
#  [b'manager' b'schedule' b'dep1' b'dep1' b'write' b'res1' b'proj1'
#   b'proj3' b'proj1' b'res2' b'true' b'coding' b'coding' b'true']
#  [b'accountant' b'task' b'dep1' b'dep2' b'setcost' b'res1' b'proj3'
# ...

# %%
import numpy as np
from sklearn.cluster import KMeans
#km = KMeans(n_clusters=5).fit(data)

cluster_map = pd.DataFrame()
cluster_map['data_index'] = data.index.values
cluster_map['cluster'] = km.labels_

valuescount=pd.DataFrame()
temp=[]

for i in range(0, 9):
    ind=cluster_map.cluster == i
    #print(ind)

# %%
cluster_map
ndf=pd.concat([data,cluster_map], axis=1)
ndf
# Out:
#            adminrole         type udepartment odepartment        action  \
# 0         b'manager'    b'budget'     b'dep1'     b'dep1'    b'approve'
# 1         b'manager'  b'schedule'     b'dep2'     b'dep1'       b'read'
# 2         b'manager'    b'budget'     b'dep1'     b'dep1'    b'approve'
# 3         b'planner'  b'schedule'     b'dep2'     b'dep1'      b'write'
# 4      b'accountant'      b'task'     b'dep1'     b'dep1'  b'setstatus'
# 5         b'manager'    b'budget'     b'dep1'     b'dep1'    b'approve'
# 6      b'accountant'  b'schedule'     b'dep2'     b'dep1'       b'read'
# 7         b'manager'  b'schedule'     b'dep1'     b'dep1'      b'write'
# 8         b'auditor'    b'budget'     b'dep2'     b'dep1'       b'read'
# 9         b'manager'  b'schedule'     b'dep2'     b'dep2'       b'read'
# 10        b'manager'    b'budget'     b'dep1'     b'dep1'    b'approve'
# 11        b'planner'  b'schedule'     b'dep1'     b'dep1'      b'write'
# ...

# %%
cat_columns = ndf.select_dtypes(['category']).columns

print(cat_columns)

ndf[cat_columns] = ndf[cat_columns].apply(lambda x: x.cat.codes)

#print(ndf)




temp = pd.DataFrame()
c= pd.DataFrame()
#getting values of each cluster and corr 
for i in range(11):
    temp = ndf.loc[ndf['cluster'] == i]
    corr= temp.corr()
    #print(corr)
# Out:
# Index(['adminrole', 'type', 'udepartment', 'odepartment', 'action', 'resource',
#        'uprojectsled', 'uprojects', 'oproject', 'utasks', 'proprietary',
#        'uexpertise', 'oexpertise', 'isemployee'],
#       dtype='object')

# %%
#name= [i 'corr.csv']
file = open('10corr.csv',"r+") 
temp = ndf.loc[ndf['cluster'] == 9]
corr= temp.corr()
corr.to_csv('10corr.csv')
file.close()

# %%
#counting values in each cluster
    #for column in temp:
        #print(temp[column].value_counts())

# %%
columns=['adminrole','type','udepartment','odepartment','action','resource','uprojectsled',
                       'uprojects','oproject','utasks','proprietary','uexpertise','oexpertise',
                        'isemployee']
with open("cval.csv", 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)


    clustervalues0=ndf.groupby(['cluster']).adminrole.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues1=ndf.groupby(['cluster']).type.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues2=ndf.groupby(['cluster']).udepartment.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues3=ndf.groupby(['cluster']).odepartment.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues4=ndf.groupby(['cluster']).action.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues5=ndf.groupby(['cluster']).resource.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues6=ndf.groupby(['cluster']).uprojectsled.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues7=ndf.groupby(['cluster']).uprojects.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues8=ndf.groupby(['cluster']).oproject.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues9=ndf.groupby(['cluster']).utasks.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues10=ndf.groupby(['cluster']).proprietary.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues11=ndf.groupby(['cluster']).uexpertise.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues12=ndf.groupby(['cluster']).oexpertise.value_counts()
    #spamwriter.writerow(clustervalues)
    clustervalues13=ndf.groupby(['cluster']).isemployee.value_counts()
    clustervalues= pd.concat([clustervalues0,clustervalues1,clustervalues2,clustervalues3,clustervalues4,clustervalues5,
                             clustervalues6,clustervalues7,clustervalues8,clustervalues9,clustervalues10,clustervalues11,
                             clustervalues12,clustervalues13])
    #print(clustervalues)
    spamwriter.writerow([clustervalues8,clustervalues9])
#for col in columns:
#    clustervalues=ndf.groupby(['cluster']).[col].value_counts()
#    print(clustervalues)

file = open("cval.csv","r+") 
clustervalues.to_csv('cval.csv')
file.close() 

clustervalue=clustervalue.groupby(['cluster']).count()
#clustervalue
#clustervalues=clustervalues.groupby(['cluster']).
#clustervalues['cluster'].corr(method='pearson', min_periods=1)
clustervalues
# Out:
# cluster  adminrole
# 0        b'accountant'     771
#          b'manager'        103
#          b'planner'         59
#          b'auditor'         46
# 1        b'planner'       1075
#          b'accountant'     312
#          b'manager'        269
#          b'auditor'        227
# 2        b'auditor'        730
#          b'manager'        123
#          b'accountant'     102
#          b'planner'         45
# 3        b'auditor'        366
#          b'manager'        275
#          b'accountant'      46
#          b'planner'         23
# 4        b'manager'        510
#          b'auditor'        187
#          b'accountant'     155
#          b'planner'        153
# 5        b'planner'        804
#          b'manager'        403
#          b'accountant'     340
#          b'auditor'        227
# 6        b'accountant'     511
#          b'manager'        142
#          b'planner'         30
#          b'auditor'         27
# 7        b'planner'        372
# ...

# %%
"""clustervalues=ndf.groupby(['cluster']).describe()
print(clustervalues)
clustervalues=ndf.groupby(['cluster']).count()
print(clustervalues)
clustervalues=ndf.groupby(['cluster']).nunique()
print(clustervalues)"""

clustervalues=ndf.groupby(['cluster']).nunique()
print(clustervalues)
# Out:
#          adminrole  type  udepartment  odepartment  action  resource  \
# cluster
# 0                4     3            2            2       7         5
# 1                4     3            2            2       5         5
# 2                4     3            2            2       5         5
# 3                4     3            2            2       4         5
# 4                4     3            2            2       6         5
# 5                4     3            2            2       6         5
# 6                4     3            2            2       6         5
# 7                4     3            2            2       5         5
# 8                4     2            2            2       3         5
# 9                4     3            2            2       5         5
# 10               4     3            2            2       4         5
#
#          uprojectsled  uprojects  oproject  utasks  proprietary  uexpertise  \
# cluster
# ...

# %%
#,'type','udepartment','odepartment','action','resource','uprojectsled',
#                        'uprojects','oproject','utasks','proprietary','uexpertise','oexpertise',
#                        'isemployee'
columns=['adminrole','type','udepartment','odepartment','action','resource','uprojectsled',
                       'uprojects','oproject','utasks','proprietary','uexpertise','oexpertise',
                        'isemployee']
valuescount=pd.DataFrame()
temp=[]
for col in columns:
    temp=df[col].value_counts().to_dict()
    #print(temp)

# %%
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 852, cost: 62431.0
# Run 1, iteration: 2/100, moves: 43, cost: 62431.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1507, cost: 64868.0
# Run 1, iteration: 2/100, moves: 0, cost: 64868.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3590, cost: 63753.0
# Run 1, iteration: 2/100, moves: 1538, cost: 63753.0
# Huang: 8.8 seconds
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2677, cost: 90356.30731304701
# Run 1, iteration: 2/100, moves: 972, cost: 89718.2454691917
# Run 1, iteration: 3/100, moves: 371, cost: 89605.5015574143
# Run 1, iteration: 4/100, moves: 129, cost: 89582.38284928243
# Run 1, iteration: 5/100, moves: 135, cost: 89575.06079444659
# ...
